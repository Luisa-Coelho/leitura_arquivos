# %%
from pathlib import Path
import pandas as pd

PATH = Path('.').resolve()

heroes = pd.read_csv("picks_Data.csv")
heroes
# Out:
#        loosing_hero_id_1  loosing_hero_id_2  loosing_hero_id_3  \
# 0                     18                 28                 43
# 1                     47                 72                 78
# 2                     21                 51                 65
# 3                     11                 26                 83
# 4                     15                 16                 21
# ...                  ...                ...                ...
# 71430                 11                 20                 36
# 71431                 42                 85                 89
# 71432                  7                 12                 21
# 71433                 44                 53                 64
# 71434                 23                 30                 44
#
#        loosing_hero_id_4  loosing_hero_id_5  winning_hero_id_1  \
# 0                     75                 84                 60
# 1                     86                107                 11
# ...

# %%
heroes =  heroes.astype(str)  
heroes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 71435 entries, 0 to 71434
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   loosing_hero_id_1  71435 non-null  object
#  1   loosing_hero_id_2  71435 non-null  object
#  2   loosing_hero_id_3  71435 non-null  object
#  3   loosing_hero_id_4  71435 non-null  object
#  4   loosing_hero_id_5  71435 non-null  object
#  5   winning_hero_id_1  71435 non-null  object
#  6   winning_hero_id_2  71435 non-null  object
#  7   winning_hero_id_3  71435 non-null  object
#  8   winning_hero_id_4  71435 non-null  object
#  9   winning_hero_id_5  71435 non-null  object
# dtypes: object(10)
# memory usage: 5.5+ MB

# %%
heroes.describe()
# Out:
#        loosing_hero_id_1 loosing_hero_id_2 loosing_hero_id_3  \
# count              71435             71435             71435
# unique                90               100               107
# top                 b'7'             b'20'             b'50'
# freq                6498              3115              2397
#
#        loosing_hero_id_4 loosing_hero_id_5 winning_hero_id_1  \
# count              71435             71435             71435
# unique               105                97                90
# top                b'86'            b'101'              b'7'
# freq                3049              3807              6432
#
#        winning_hero_id_2 winning_hero_id_3 winning_hero_id_4 winning_hero_id_5
# count              71435             71435             71435             71435
# unique               101               105               107                99
# top                b'20'             b'50'             b'86'            b'101'
# ...
