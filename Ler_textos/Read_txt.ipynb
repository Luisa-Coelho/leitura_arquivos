# %%
### Agora tem que fazer a separação por sílabas

# %%
import re
# Open the file in read mode/ using with you don´t need to close the file in the end
with open("sample.txt",'r',encoding="utf8") as text:
    text = text.readlines()

# open both files
#with open('sample.txt','r') as text, open('no_caracteres.txt','a') as text_plain:
    # read content from first file
 #   for line in text:
        # append content to second file
  #      text_plain.write(line)
        #text_plain = re.sub(r"[^a-zA-Z0-9]", "", text_plain)


# Create an empty dictionary
d = dict()

# Loop through each line of the file
for line in text:
    # Remove the leading spaces and newline character
    line = line.strip()
# Convert the characters in line to
# lowercase to avoid case mismatch
    line = line.lower()

# Removing special characters and spliting the line into words
    words = re.sub(r'[^\w\s]', '', line)
    words = words.split(" ")
        
    # Iterate over each word in line
    for word in words:
        # Check if the word is already in dictionary
        if word in d:
            # Increment count of word by 1
            d[word] = d[word] + 1
        
        else:
            # Add the word to dictionary with count 1
            d[word] = 1

# Print the contents of dictionary
for key in list(d.keys()):
    print(key, ":", d[key])
# Out:
# o : 45
# diário : 30
# oficial : 6
# da : 25
# união : 3
# dou : 5
# é : 18
# um : 11
# importante : 2
# veículo : 1
# de : 93
# comunicação : 1
# nacional : 5
# criado : 1
# em : 29
# 1 : 3
# outubro : 1
# 1862 : 1
# sancionado : 1
# pela : 5
# lei : 6
# imperial : 1
# nº : 1
# 1177 : 1
# após : 2
# 54 : 1
# anos : 1
# chegada : 1
# corte : 1
# portuguesa : 1
# ao : 3
# brasil : 6
# sua : 1
# função : 1
# desde : 3
# então : 1
# divulgar : 1
# as : 5
# leis : 2
# e : 61
# normas : 3
# do : 50
# país : 3
# forma : 2
# simples : 1
# direta : 1
# documental : 1
# sem : 2
# qualquer : 3
# tipo : 1
# contestação : 1
# ou : 11
# queixa : 1
# sendo : 1
# este : 1
# instrumento : 1
# que : 28
# governo : 3
# presta : 1
# contas : 2
# à : 6
# sociedade : 5
# rocha : 1
# 2020 : 2
# atualmente : 2
# pode : 3
# ser : 5
# acessado : 1
# através : 6
# link : 1
# imprensa : 1
# permitindo : 2
# buscas : 3
# por : 14
# palavraschave : 1
# até : 2
# mesmo : 2
# uma : 24
# busca : 6
# avançada : 1
# ...

# %%
file=open("sample.txt",'r',encoding="utf8")

print(file.read())
# Out:
# O Diário Oficial da União (DOU) é um importante veículo de comunicação nacional, criado em 1° de outubro
# de 1862, sancionado pela Lei Imperial nº 1.177, após 54 anos da chegada da corte portuguesa ao Brasil. Sua
# função, desde então, é divulgar as leis e normas do país, de forma simples, direta e documental, sem qualquer
# tipo de contestação ou queixa, sendo este o instrumento em que o governo presta contas à sociedade (Rocha,
# 2020). Atualmente o DOU pode ser acessado através do link da Imprensa Nacional permitindo buscas por
# palavras-chave ou até mesmo uma busca avançada que permite o filtro por seções, data, busca por títulos ou
# conteúdo, entre outros. As seções básicas do DOU consistem em:
# 1. Leis, decretos, resoluções, instruções normativas, portarias e outros atos normativos de interesse geral;
# 2. Atos de interesse dos servidores da Administração Pública Federal;
# ...
